# %% [markdown]
# <a href="https://colab.research.google.com/github/adam-pearman/advent_of_code/blob/main/2022/day_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Part 1

# %%
with open('input.txt') as input:
  total = 0
  for line in input:
    line = line.rsplit()[0]
    mid = len(line) // 2
    l, r = set(line[:mid]), set(line[mid:])
    ans = (ord((l & r).pop())) - 96
    if ans < 0:
      ans += 58
    total += ans
  print(total)
# Out:
# 8088

# %% [markdown]
# #Part 2

# %%
with open('input.txt') as input:
  total = 0
  group = []
  for line in input:
    line = line.rsplit()[0]
    group.append(set(line))
    if len(group) == 3:
      ans = ord((group[0] & group[1] & group[2]).pop()) - 96
      if ans < 0:
        ans += 58
      total += ans
      group = []
  print(total)
# Out:
# 2522
